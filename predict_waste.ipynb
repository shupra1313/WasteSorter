# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from keras.models import Sequential, Model, load_model
import os
from keras.preprocessing import image
from keras.applications.inception_v3 import (
    InceptionV3, preprocess_input, decode_predictions)
import numpy as np
from PIL import Image

# %%
labels = pd.read_csv("labels.csv")
labels
# Out:
#                Label  Index
# 0  compostible waste      0
# 1   Recyclable waste      1

# %%
labels = pd.DataFrame.from_csv("labels.csv")
# Out:
# C:\Users\shrut\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls

# %%
labels.index
# Out:
# Index(['compostible waste', 'Recyclable waste'], dtype='object', name='Label')

# %%
names = ['compostible waste', 'Recyclable waste']

# %%
model = load_model("model.05-0.94.hdf5")

# %%
images = ["compostable_waste1.jpg", "compostable_waste2.jpg", "recyclable_wastes1.jpg", "recyclable_wastes2.jpg", "recyclable_wastes3.jpg","recyclable_wastes4.jpg","recyclable_wastes5.jpg", "recyclable_wastes6.jpg", "recyclable_wastes7.jpg"]

# %%
image_path_array = []
for img in images:
    image_path = os.path.join("dataset/prediction/" + img)
    image_path_array.append(image_path)
print(image_path_array)
# Out:
# ['dataset/prediction/compostable_waste1.jpg', 'dataset/prediction/compostable_waste2.jpg', 'dataset/prediction/recyclable_wastes1.jpg', 'dataset/prediction/recyclable_wastes2.jpg', 'dataset/prediction/recyclable_wastes3.jpg', 'dataset/prediction/recyclable_wastes4.jpg', 'dataset/prediction/recyclable_wastes5.jpg', 'dataset/prediction/recyclable_wastes6.jpg', 'dataset/prediction/recyclable_wastes7.jpg']

# %%
image_path = image_path_array[0]
img = image.load_img(image_path, target_size=(299, 299))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x = preprocess_input(test_image)

# %%
plt.imshow(x[0])
predictions = model.predict(x)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'compostible waste'

# %%
image_path = image_path_array[3]
img = image.load_img(image_path, target_size=(299, 299))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x1 = preprocess_input(test_image)
plt.imshow(x1[0])
predictions = model.predict(x1)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
image_path = image_path_array[1]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x1 = preprocess_input(test_image)
plt.imshow(x1[0])
predictions = model.predict(x1)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'compostible waste'

# %%
image_path = image_path_array[2]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x2 = preprocess_input(test_image)
plt.imshow(x2[0])
predictions = model.predict(x2)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
image_path = image_path_array[3]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x2 = preprocess_input(test_image)
plt.imshow(x2[0])
predictions = model.predict(x2)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
image_path = image_path_array[5]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x2 = preprocess_input(test_image)
plt.imshow(x2[0])
predictions = model.predict(x2)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
image_path = image_path_array[6]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x2 = preprocess_input(test_image)
plt.imshow(x2[0])
predictions = model.predict(x2)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
image_path = image_path_array[8]
img = image.load_img(image_path, target_size=(224, 224))
plt.imshow(img)

# %%
test_image = image.img_to_array(img)
test_image = np.expand_dims(test_image, axis=0)
x2 = preprocess_input(test_image)
plt.imshow(x2[0])
predictions = model.predict(x2)
names[predictions.argmax(axis=1)[0]]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 'Recyclable waste'

# %%
from flask import Flask, render_template, request, redirect
import os
import glob
from keras.models import Model
import pandas as pd
from keras import backend as K
import keras
import keras.applications.inception_v3 as incept
from keras.preprocessing import image
from keras.models import load_model
from keras import backend as K
import numpy as np
from keras.preprocessing.image import img_to_array,load_img
import h5py
import numpy

def create_model():
    K.clear_session()
    filename = 'model.05-0.94.hdf5'
    model = load_model(filename)
    return model

# prediction
def call_predict(images, imageupload):
    model = create_model()
    for image_name in images:
        image_path = imageupload + "/" + image_name
        print(f"imagepath: {image_path}")
        img = load_img(image_path,target_size = (299,299)) #Load the image and set the target size to the size of input of our model
        x = img_to_array(img) #Convert the image to array
        x = np.expand_dims(x,axis=0) #Convert the array to the form (1,x,y,z)
        x = incept.preprocess_input(x) # Use the preprocess input function o subtract the mean of all the images
        predictions = model.predict(x) # Store the argmax of the predictions
        prediction = predictions[0][0]
        if prediction < 0.5:
            print("recyclable")
            prediction_category = 'recyclable'
        elif prediction >= 0.5:
            print("compostable")
            prediction_category = 'compostable'

    return prediction_category

app = Flask(__name__)
app.config['UPLOAD_FOLDER'] = 'static/uploads'

####################### Define routes ###########################
@app.route("/",  methods=['GET', 'POST'])
def index():
    print("upload click")
    print(request.method)
    if request.method == 'POST':
        if request.files.get('file'):
            images = request.files.getlist("file") # convert multidict to dict
            print(f"Images: {images}")
            # Remove all the files
            files = glob.glob(app.config['UPLOAD_FOLDER']+'/*')
            # print(files)
            for f in files:
                os.remove(f)

            filenames = []
            #save the image
            for image in images:     #image will be the key
                # create a path to the uploads folder
                filepath = os.path.join(app.config['UPLOAD_FOLDER'], image.filename)
                image.save(filepath)
                filenames.append(image.filename)
                print(filenames)

            category = call_predict(filenames, app.config['UPLOAD_FOLDER'])

            return render_template('index.html', prediction=category, image=filepath)
    else:
        # Print an error message
        print("Error: Image not recognized")

        return render_template("index.html")


if __name__ == '__main__':
    app.run(debug=True)
